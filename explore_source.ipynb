# %%
import pandas as pd
from gbad.converter.preprocessors import SourceCSVPreprocessor

# %%
SOURCE_PATH="gbad/mapping/source/DESCRIPTION.csv"
joint_office_col = 'DATEOFF:OFFICEAB:AB_REFA:OFFICEC:C_REFA'
separate_office_cols = ['DATEOFF', 'OFFICEAB', 'AB_REFA', 'OFFICEC', 'C_REFA']
numbered_office_cols = []
for i in range(1, 21):
    numbered_office_cols.extend([f"{col}_{i}" for col in separate_office_cols])
len(numbered_office_cols)
# Out:
# 100

# %%
preprocessor = SourceCSVPreprocessor(SOURCE_PATH, '', index_col='SISN')
df = preprocessor.source_df.copy()

# %%
df[joint_office_col].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 23174 entries, 1 to 25009
# Series name: DATEOFF:OFFICEAB:AB_REFA:OFFICEC:C_REFA
# Non-Null Count  Dtype
# --------------  -----
# 23172 non-null  object
# dtypes: object(1)
# memory usage: 362.1+ KB

# %%
sorted_df = df.sort_values(by=joint_office_col, key=lambda x: x.str.len(), ascending=False)
sorted_df[joint_office_col]
# Out:
# SISN
# 3967     1969-1972 : Department of Colleges and Univers...
# 5307     1949-1968 : Department of Education : AA3 : Co...
# 14466    1986-1991 : Ministry of Industry, Trade and Te...
# 3996     1958-1963 : Department of Travel and Publicity...
# 6492     1806-1827 : Surveyor General's Office : BA84 :...
#                                ...
# 13002                                            : : : : :
# 12662                                            : : : : :
# 6192                                                   : :
# 6045                                                   NaN
# 10762                                                  NaN
# Name: DATEOFF:OFFICEAB:AB_REFA:OFFICEC:C_REFA, Length: 23174, dtype: object

# %%
sorted_df[joint_office_col].iloc[0]  # Longest value, looks like i=20 based on \d{4}-\d{4}
# Out:
# '1969-1972 : Department of Colleges and Universities : AA77 : : : 1972-1973 : Ministry of Colleges and Universities : AA4 : : : 1973-1975 : Ministry of Colleges and Universities : AA4 : Cultural Affairs Division : CA132 : 1975-1976 : Ministry of Culture and Recreation : AA5 : Arts Support Division : CA170 : 1976-1979 : Ministry of Culture and Recreation : AA5 : Arts Division : CA665 : 1979-1980 : Ministry of Culture and Recreation : AA5 : Arts, Sports and Fitness Division : CA657 : 1980-1981 : Ministry of Culture and Recreation : AA5 : Culture Division : CA666 : 1981-1983 : Ministry of Culture and Recreation : AA5 : Arts, Heritage and Libraries Division : CA661 : 1983-1984 : Ministry of Citizenship and Culture : AA9 : Culture and Regional Services Division : CA663 : 1984-1987 : Ministry of Citizenship and Culture : AA9 : Culture Division : CA664 : 1987-1993 : Ministry of Culture and Communications : AA10 : Culture Division : CA664 : 1993-1995 : Ministry of Culture, Tourism and Recreation : AA7 : Office of the Deputy Minister : CA631 : 1995-1998 : Ministry of Citizenship, Culture and Recreation : AA11 : Office of the Deputy Minister : CA632 : 1998-2001 : Ministry of Citizenship, Culture and Recreation : AA11 : Office of the Deputy Minister : CA632 : 2001-2002 : Ministry of Tourism, Culture and Recreation : AA122 : Office of the Deputy Minister : CA2219 : 2001-2003 : Ministry of Citizenship : AA121 : Office of the Deputy Minister of Citizenship : CA2157 : 2003-2006 : Ministry of Citizenship and Immigration : AA134 : Office of the Deputy Minister of Citizenship : CA2157 : 2002-2010 : Ministry of Culture : AA124 : Office of the Deputy Minister : CA2220 : 2010-2011 : Ministry of Tourism and Culture : AA153 : : : 2011-2018 : Ministry of Tourism, Culture and Sport : AA154 : : :'

# %%
def split_by_colon(value: str, expect_num_cols: int):
    SEP = ' : '

    def fix_colon_spacing(value: str) -> str:
        while ': :' in value:
            value = value.replace(': :', ':  :')
        value = value[:-2] if value.endswith(' :') else value  # to fix any ending colon
        value = value[2:] if value.startswith(': ') else value  # to fix any starting colon
        return value

    return preprocessor.separate_value(fix_colon_spacing(value), expect_num_cols, sep=SEP)

# %%
# Column split #6
preprocessor.column_split(split_by_colon, joint_office_col, numbered_office_cols)
# Out:
# Splitting column 'DATEOFF:OFFICEAB:AB_REFA:OFFICEC:C_REFA' into ['DATEOFF_1', 'OFFICEAB_1', 'AB_REFA_1', 'OFFICEC_1', 'C_REFA_1', 'DATEOFF_2', 'OFFICEAB_2', 'AB_REFA_2', 'OFFICEC_2', 'C_REFA_2', 'DATEOFF_3', 'OFFICEAB_3', 'AB_REFA_3', 'OFFICEC_3', 'C_REFA_3', 'DATEOFF_4', 'OFFICEAB_4', 'AB_REFA_4', 'OFFICEC_4', 'C_REFA_4', 'DATEOFF_5', 'OFFICEAB_5', 'AB_REFA_5', 'OFFICEC_5', 'C_REFA_5', 'DATEOFF_6', 'OFFICEAB_6', 'AB_REFA_6', 'OFFICEC_6', 'C_REFA_6', 'DATEOFF_7', 'OFFICEAB_7', 'AB_REFA_7', 'OFFICEC_7', 'C_REFA_7', 'DATEOFF_8', 'OFFICEAB_8', 'AB_REFA_8', 'OFFICEC_8', 'C_REFA_8', 'DATEOFF_9', 'OFFICEAB_9', 'AB_REFA_9', 'OFFICEC_9', 'C_REFA_9', 'DATEOFF_10', 'OFFICEAB_10', 'AB_REFA_10', 'OFFICEC_10', 'C_REFA_10', 'DATEOFF_11', 'OFFICEAB_11', 'AB_REFA_11', 'OFFICEC_11', 'C_REFA_11', 'DATEOFF_12', 'OFFICEAB_12', 'AB_REFA_12', 'OFFICEC_12', 'C_REFA_12', 'DATEOFF_13', 'OFFICEAB_13', 'AB_REFA_13', 'OFFICEC_13', 'C_REFA_13', 'DATEOFF_14', 'OFFICEAB_14', 'AB_REFA_14', 'OFFICEC_14', 'C_REFA_14', 'DATEOFF_15', 'OFFICEAB_15', 'AB_REFA_15', 'OFFICEC_15', 'C_REFA_15', 'DATEOFF_16', 'OFFICEAB_16', 'AB_REFA_16', 'OFFICEC_16', 'C_REFA_16', 'DATEOFF_17', 'OFFICEAB_17', 'AB_REFA_17', 'OFFICEC_17', 'C_REFA_17', 'DATEOFF_18', 'OFFICEAB_18', 'AB_REFA_18', 'OFFICEC_18', 'C_REFA_18', 'DATEOFF_19', 'OFFICEAB_19', 'AB_REFA_19', 'OFFICEC_19', 'C_REFA_19', 'DATEOFF_20', 'OFFICEAB_20', 'AB_REFA_20', 'OFFICEC_20', 'C_REFA_20']

# %%
def split_by_hyphen(value: str, expect_num_cols: int):
    return preprocessor.separate_value(value, expect_num_cols, sep='-')

# Column split #7
DATEOFF_COLNAME  = 'DATEOFF'
DATE_BEGINNING_SUFFIX = '_BEGINNING'
DATE_END_SUFFIX = '_END'
joint_dateoff_colnames = [f'{DATEOFF_COLNAME}_{i}' for i in range(1, 21)]
for col in joint_dateoff_colnames:
    separate_dateoff_cols = [f"{col}{DATE_BEGINNING_SUFFIX}", f"{col}{DATE_END_SUFFIX}"]
    preprocessor.column_split(split_by_hyphen, col, separate_dateoff_cols)
# Out:
# Splitting column 'DATEOFF_1' into ['DATEOFF_1_BEGINNING', 'DATEOFF_1_END']
#
# Splitting column 'DATEOFF_2' into ['DATEOFF_2_BEGINNING', 'DATEOFF_2_END']
#
# Splitting column 'DATEOFF_3' into ['DATEOFF_3_BEGINNING', 'DATEOFF_3_END']
#
# Splitting column 'DATEOFF_4' into ['DATEOFF_4_BEGINNING', 'DATEOFF_4_END']
#
# Splitting column 'DATEOFF_5' into ['DATEOFF_5_BEGINNING', 'DATEOFF_5_END']
#
# Splitting column 'DATEOFF_6' into ['DATEOFF_6_BEGINNING', 'DATEOFF_6_END']
#
# Splitting column 'DATEOFF_7' into ['DATEOFF_7_BEGINNING', 'DATEOFF_7_END']
#
# Splitting column 'DATEOFF_8' into ['DATEOFF_8_BEGINNING', 'DATEOFF_8_END']
#
# Splitting column 'DATEOFF_9' into ['DATEOFF_9_BEGINNING', 'DATEOFF_9_END']
#
# Splitting column 'DATEOFF_10' into ['DATEOFF_10_BEGINNING', 'DATEOFF_10_END']
#
# Splitting column 'DATEOFF_11' into ['DATEOFF_11_BEGINNING', 'DATEOFF_11_END']
#
# Splitting column 'DATEOFF_12' into ['DATEOFF_12_BEGINNING', 'DATEOFF_12_END']
#
# Splitting column 'DATEOFF_13' into ['DATEOFF_13_BEGINNING', 'DATEOFF_13_END']
#
# Splitting column 'DATEOFF_14' into ['DATEOFF_14_BEGINNING', 'DATEOFF_14_END']
#
# Splitting column 'DATEOFF_15' into ['DATEOFF_15_BEGINNING', 'DATEOFF_15_END']
#
# Splitting column 'DATEOFF_16' into ['DATEOFF_16_BEGINNING', 'DATEOFF_16_END']
#
# Splitting column 'DATEOFF_17' into ['DATEOFF_17_BEGINNING', 'DATEOFF_17_END']
#
# Splitting column 'DATEOFF_18' into ['DATEOFF_18_BEGINNING', 'DATEOFF_18_END']
#
# Splitting column 'DATEOFF_19' into ['DATEOFF_19_BEGINNING', 'DATEOFF_19_END']
#
# Splitting column 'DATEOFF_20' into ['DATEOFF_20_BEGINNING', 'DATEOFF_20_END']

# %%
preprocessor.source_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23174 entries, 1 to 25009
# Columns: 216 entries, REFD to DATEOFF_20_END
# dtypes: object(216)
# memory usage: 38.9+ MB

# %%
i = 5
cols = [f"{col}_{i}" for col in separate_office_cols]
cols.extend([f"{DATEOFF_COLNAME}_{i}{DATE_BEGINNING_SUFFIX}"])
cols.extend([f"{DATEOFF_COLNAME}_{i}{DATE_END_SUFFIX}"])
preprocessor.source_df.loc[5142, cols]
# Out:
# DATEOFF_5                                      1984-1992
# OFFICEAB_5             Ministry of Correctional Services
# AB_REFA_5                                           AA81
# OFFICEC_5                            Operations Division
# C_REFA_5                                          CA1495
# DATEOFF_5_BEGINNING                                 1984
# DATEOFF_5_END                                       1992
# Name: 5142, dtype: object

# %%
preprocessor.source_df[joint_office_col].loc[5142]
# Out:
# '1953-1969 : Department of the Attorney General : AA28 : Probation Services Branch : CA1492 : 1969-1972 : Department of Justice : AA73 : Probation Services Branch : CA1492 : 1972-1978 : Ministry of Correctional Services : AA81 : Adult Division : CA1497 : 1978-1984 : Ministry of Correctional Services : AA81 : Probation and Parole Service : CA1496 : 1984-1992 : Ministry of Correctional Services : AA81 : Operations Division : CA1495 :'
